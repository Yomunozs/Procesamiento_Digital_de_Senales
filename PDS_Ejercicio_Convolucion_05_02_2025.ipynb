# %% [markdown]
# <a href="https://colab.research.google.com/github/Yomunozs/Procesamiento_Digital_de_Senales/blob/main/PDS_Ejercicio_Convolucion_05_02_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider

# %%
# Define the parameters for each sine wave
frequencies = [10, 25, 30]  # Frequencies of the sine waves
amplitudes = [1, 0.5, 0.25]  # Amplitudes of the sine waves
duration = 5 # Duration of the signal in seconds
sampling_rate_1 = 100  # Sampling rate in Hz

# Generate time values
time_1 = np.linspace(0, duration, duration * sampling_rate_1)

# Initialize the signal with zeros
signal_1 = np.zeros(len(time_1))

# Generate each sine wave and add it to the signal
for freq, amp in zip(frequencies, amplitudes):
  wave = amp * np.sin(2 * np.pi * freq * time_1)
  signal_1 += wave

plt.figure(figsize=(10, 4))
plt.plot(time_1, signal_1)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Combined Sine Waves')
plt.grid(True)
plt.show()

# %%
f_signal_2 = 5
signal_2 = 1 * np.sin(2 * np.pi * f_signal_2 * time_1)

plt.figure(figsize=(10, 4))
plt.plot(time_1, signal_2)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Combined Sine Waves')
plt.grid(True)
plt.show()

# %%
def update_plot(f_signal_2):
    signal_2 = 1 * np.sin(2 * np.pi * f_signal_2 * time_1)
    convolution_result = np.convolve(signal_1, signal_2, mode='same')

    plt.figure(figsize=(20, 6))
    plt.plot(time_1, convolution_result)
    plt.ylim(-300, 300)
    plt.xlim(0, 5)
    plt.grid(True)
    plt.title('Convolution Result')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    plt.tight_layout()
    plt.show()

interact(update_plot, f_signal_2=IntSlider(min=0, max=40, step=2, value=0, continuous_update=True));
# Out:
# interactive(children=(IntSlider(value=0, description='f_signal_2', max=40, step=2), Output()), _dom_classes=('…

# %%
f_signal_3 = 5
signal_3 = 1 * np.sin(2 * np.pi * f_signal_3 * time_1)

# signal_3[0:int(2*sampling_rate_1)] = 0
signal_3[int(1*sampling_rate_1):int(5*sampling_rate_1)] = 0

plt.figure(figsize=(10, 4))
plt.plot(time_1, signal_3)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Combined Sine Waves')
plt.grid(True)
plt.show()

# %%
def update_plot_win(f_signal_3):

    signal_3 = 1 * np.sin(2 * np.pi * f_signal_3 * time_1)
    signal_3[int(1*sampling_rate_1):int(5*sampling_rate_1)] = 0

    convolution_result = np.convolve(signal_1, signal_3, mode='same')

    plt.figure(figsize=(20, 6))
    plt.plot(time_1, convolution_result)
    # plt.ylim(-300, 300)
    plt.xlim(0, 5)
    plt.grid(True)
    plt.title('Convolution Result')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    plt.tight_layout()
    plt.show()

interact(update_plot_win, f_signal_3=IntSlider(min=0, max=40, step=2, value=0, continuous_update=True));
# Out:
# interactive(children=(IntSlider(value=0, description='f_signal_3', max=40, step=2), Output()), _dom_classes=('…
